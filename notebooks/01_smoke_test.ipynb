# %%
import pandas as pd

df = pd.read_csv("../data/sample.csv")
print("Shape:", df.shape)
print()
print(df.head())
print()
print(df.describe())
# Out:
# Shape: (5, 3)
#
#   student  score  passed
# 0   Hamza     88    True
# 1   Ahmad     70    True
# 2    Sara     55   False
# 3    Lina     92    True
# 4    Omar     40   False
#
#            score
# count   5.000000
# mean   69.000000
# std    21.954498
# min    40.000000
# 25%    55.000000
# 50%    70.000000
# 75%    88.000000
# max    92.000000
